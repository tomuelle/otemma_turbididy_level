# %%
# %run ./CombinedData.ipynb
# Out:
# <div>
#
#
#             <div id="e98c0742-24ed-4e9f-a05e-2ba1c975b4e3" class="plotly-graph-div" style="height:960px; width:960px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e98c0742-24ed-4e9f-a05e-2ba1c975b4e3")) {
#                     Plotly.newPlot(
#                         'e98c0742-24ed-4e9f-a05e-2ba1c975b4e3',
# ...
